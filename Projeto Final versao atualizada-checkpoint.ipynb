# %% [markdown]
# # Projeto Final - Fifa 18 More Complete Player Dataset

# %%
#importar todas as bibliotecas necessárias

import pandas as pd
from pandas import DataFrame
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import math as math
from scipy import stats
import statsmodels.api as sm
from scipy.stats import uniform, expon, norm, probplot, percentileofscore, t
import statsmodels.api as sm
import xgboost as xgb

# %%
#rodar o dataset

fifa = pd.read_csv("CompleteDataset.csv")
# Out:
# C:\Users\VICTOR HABIB\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Análise exploratória

# %%
fifa.head(10)
# Out:
#    Unnamed: 0               Name  Age  \
# 0           0  Cristiano Ronaldo   32
# 1           1           L. Messi   30
# 2           2             Neymar   25
# 3           3          L. Suárez   30
# 4           4           M. Neuer   31
# 5           5     R. Lewandowski   28
# 6           6             De Gea   26
# 7           7          E. Hazard   26
# 8           8           T. Kroos   27
# 9           9         G. Higuaín   29
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
# 5  https://cdn.sofifa.org/48/18/players/188545.png      Poland
# 6  https://cdn.sofifa.org/48/18/players/193080.png       Spain
# 7  https://cdn.sofifa.org/48/18/players/183277.png     Belgium
# 8  https://cdn.sofifa.org/48/18/players/182521.png     Germany
# 9  https://cdn.sofifa.org/48/18/players/167664.png   Argentina
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# 4  https://cdn.sofifa.org/flags/21.png       92         92
# 5  https://cdn.sofifa.org/flags/37.png       91         91
# 6  https://cdn.sofifa.org/flags/45.png       90         92
# 7   https://cdn.sofifa.org/flags/7.png       90         91
# 8  https://cdn.sofifa.org/flags/21.png       90         90
# 9  https://cdn.sofifa.org/flags/52.png       90         90
#
#                   Club                                   Club Logo  ...   \
# 0       Real Madrid CF  https://cdn.sofifa.org/24/18/teams/243.png  ...
# 1         FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/24/18/teams/73.png  ...
# 3         FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png  ...
# 4     FC Bayern Munich   https://cdn.sofifa.org/24/18/teams/21.png  ...
# 5     FC Bayern Munich   https://cdn.sofifa.org/24/18/teams/21.png  ...
# 6    Manchester United   https://cdn.sofifa.org/24/18/teams/11.png  ...
# 7              Chelsea    https://cdn.sofifa.org/24/18/teams/5.png  ...
# 8       Real Madrid CF  https://cdn.sofifa.org/24/18/teams/243.png  ...
# 9             Juventus   https://cdn.sofifa.org/24/18/teams/45.png  ...
#
#      RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  61.0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  57.0  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  59.0  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  64.0  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5  58.0  57.0  78.0  62.0  87.0  82.0  88.0  84.0  61.0  88.0
# 6   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7  59.0  47.0  81.0  61.0  87.0  87.0  82.0  88.0  64.0  82.0
# 8  76.0  72.0  87.0  82.0  81.0  81.0  77.0  80.0  78.0  77.0
# 9  51.0  46.0  71.0  52.0  84.0  79.0  87.0  82.0  55.0  87.0
#
# [10 rows x 75 columns]

# %%
#remover itens que não serão úteis na análise

fifa_limpo = fifa.drop(columns=['Unnamed: 0', 'Photo', 'Flag', 'Club Logo'])

# %%
fifa_limpo.head(10)
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  Cristiano Ronaldo   32    Portugal       94         94
# 1           L. Messi   30   Argentina       93         93
# 2             Neymar   25      Brazil       92         94
# 3          L. Suárez   30     Uruguay       92         92
# 4           M. Neuer   31     Germany       92         92
# 5     R. Lewandowski   28      Poland       91         91
# 6             De Gea   26       Spain       90         92
# 7          E. Hazard   26     Belgium       90         91
# 8           T. Kroos   27     Germany       90         90
# 9         G. Higuaín   29   Argentina       90         90
#
#                   Club   Value   Wage  Special Acceleration  ...     RB   RCB  \
# 0       Real Madrid CF  €95.5M  €565K     2228           89  ...   61.0  53.0
# 1         FC Barcelona   €105M  €565K     2154           92  ...   57.0  45.0
# 2  Paris Saint-Germain   €123M  €280K     2100           94  ...   59.0  46.0
# 3         FC Barcelona    €97M  €510K     2291           88  ...   64.0  58.0
# 4     FC Bayern Munich    €61M  €230K     1493           58  ...    NaN   NaN
# 5     FC Bayern Munich    €92M  €355K     2143           79  ...   58.0  57.0
# 6    Manchester United  €64.5M  €215K     1458           57  ...    NaN   NaN
# 7              Chelsea  €90.5M  €295K     2096           93  ...   59.0  47.0
# 8       Real Madrid CF    €79M  €340K     2165           60  ...   76.0  72.0
# 9             Juventus    €77M  €275K     1961           78  ...   51.0  46.0
#
#     RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5  78.0  62.0  87.0  82.0  88.0  84.0  61.0  88.0
# 6   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7  81.0  61.0  87.0  87.0  82.0  88.0  64.0  82.0
# 8  87.0  82.0  81.0  81.0  77.0  80.0  78.0  77.0
# 9  71.0  52.0  84.0  79.0  87.0  82.0  55.0  87.0
#
# [10 rows x 71 columns]

# %% [markdown]
# # Estatísticas descritivas

# %%
fifa_limpo.describe()
# Out:
#                 Age       Overall     Potential       Special           CAM  \
# count  17981.000000  17981.000000  17981.000000  17981.000000  15952.000000
# mean      25.144541     66.247984     71.190813   1594.095100     59.251755
# std        4.614272      6.987965      6.102199    272.151435      9.880164
# min       16.000000     46.000000     46.000000    728.000000     27.000000
# 25%       21.000000     62.000000     67.000000   1449.000000     53.000000
# 50%       25.000000     66.000000     71.000000   1633.000000     60.000000
# 75%       28.000000     71.000000     75.000000   1786.000000     66.000000
# max       47.000000     94.000000     94.000000   2291.000000     92.000000
#
#                  CB           CDM            CF            CM             ID  \
# count  15952.000000  15952.000000  15952.000000  15952.000000   17981.000000
# mean      55.550464     56.865283     59.030028     58.506833  207658.710138
# std       12.192579     10.310178      9.926988      8.888040   32291.667313
# min       25.000000     26.000000     27.000000     30.000000      16.000000
# 25%       45.000000     49.000000     53.000000     53.000000  192622.000000
# 50%       57.000000     58.000000     60.000000     59.000000  214057.000000
# 75%       65.000000     65.000000     66.000000     65.000000  231448.000000
# max       87.000000     85.000000     92.000000     87.000000  241219.000000
#
#            ...                 RB           RCB           RCM           RDM  \
# count      ...       15952.000000  15952.000000  15952.000000  15952.000000
# mean       ...          56.979689     55.550464     58.506833     56.865283
# std        ...           9.791627     12.192579      8.888040     10.310178
# min        ...          30.000000     25.000000     30.000000     26.000000
# 25%        ...          50.000000     45.000000     53.000000     49.000000
# 50%        ...          58.000000     57.000000     59.000000     58.000000
# 75%        ...          64.000000     65.000000     65.000000     65.000000
# max        ...          84.000000     87.000000     87.000000     85.000000
#
#                  RF            RM            RS            RW           RWB  \
# count  15952.000000  15952.000000  15952.000000  15952.000000  15952.000000
# mean      59.030028     60.057736     58.204050     59.359265     57.698721
# std        9.926988      9.349180      9.181392      9.978084      9.142825
# min       27.000000     28.000000     31.000000     26.000000     31.000000
# 25%       53.000000     54.000000     52.000000     53.000000     51.000000
# 50%       60.000000     61.000000     59.000000     60.000000     58.000000
# 75%       66.000000     67.000000     65.000000     66.000000     64.000000
# max       92.000000     90.000000     92.000000     91.000000     84.000000
#
#                  ST
# count  15952.000000
# mean      58.204050
# std        9.181392
# min       31.000000
# 25%       52.000000
# 50%       59.000000
# 75%       65.000000
# max       92.000000
#
# [8 rows x 31 columns]

# %%
def troca(preco):
    multiplier = preco[-1]
    preco = preco[1:-1]
    
    if multiplier == "M":
        return float(preco) * 10**(6)
    elif multiplier == "K":
        return float(preco) * 10**(3)

# %%
lista = []
for x in fifa["Value"]:
    lista.append(troca(x))

# %%
fifa["Value"] = lista

# %%
fifa["Value"].head(10)
# Out:
# 0     95500000.0
# 1    105000000.0
# 2    123000000.0
# 3     97000000.0
# 4     61000000.0
# 5     92000000.0
# 6     64500000.0
# 7     90500000.0
# 8     79000000.0
# 9     77000000.0
# Name: Value, dtype: float64

# %% [markdown]
# # Distribuição das idades dos jogadores

# %%
#dados básicos de idade

fifa.Age.describe()
# Out:
# count    17981.000000
# mean        25.144541
# std          4.614272
# min         16.000000
# 25%         21.000000
# 50%         25.000000
# 75%         28.000000
# max         47.000000
# Name: Age, dtype: float64

# %%
#média e desvio padrão mais precisos

media, dp = norm.fit(fifa.Age)

print('Média: {0}'.format(media))
print('Desvio Padrão: {0}'.format(dp))
# Out:
# Média: 25.144541460430453
# Desvio Padrão: 4.614144033551294

# %%
#idade mínima e máxima

idade_min = 16
idade_max = 47

print('Idade do jogador mais jovem: {0} anos'.format(idade_min))
print('Idade do jogador mais velho: {0} anos'.format(idade_max))
# Out:
# Idade do jogador mais jovem: 16 anos
# Idade do jogador mais velho: 47 anos

# %%
idades=[]
for dados_idade in fifa.Age:
    idades.append(dados_idade)
plt.hist(np.log(idades), density=True, bins= 40);
plt.ylabel('Densidade');
plt.xlabel('Idades');

# %%
#Verificar graficamente se a distribuição normal é um modelo adequado para as idades dos jogadores

stats.probplot(np.log(idades), dist='norm', plot=plt);

# %% [markdown]
# Percebe-se que a distribuição normal não pode ser considerada aceitável como modelo para as idades dos jogadores, pois grande parte dos pontos não se encontram sobre a linha vermelha (diagonal).

# %%
x = np.linspace(idade_min-5, idade_max+5, 1000)
y = norm.pdf(x, loc=media , scale=dp)
plt.plot(x, y)
plt.grid(True)
plt.show()

# %%
#plotar

plt.hist(np.log(idades), density=True, bins= 30)
plt.axis([idade_min-5, idade_max+5, 0, 0.09])
plt.ylabel('Densidade')
plt.xlabel('Idades')
plt.plot(x, y)
plt.show()

# %% [markdown]
# # Habilidade x Habilidades

# %%
player_attributes = pd.read_excel('AttributesDataset.xlsx')

# %%
player_attributes.dtypes
# Out:
# Acceleration          int64
# Aggression            int64
# Agility               int64
# Balance               int64
# Ball control          int64
# Composure             int64
# Crossing              int64
# Curve                 int64
# Dribbling             int64
# Finishing             int64
# Free kick accuracy    int64
# GK diving             int64
# GK handling           int64
# GK kicking            int64
# GK positioning        int64
# GK reflexes           int64
# Heading accuracy      int64
# ID                    int64
# Interceptions         int64
# Jumping               int64
# Long passing          int64
# Long shots            int64
# Marking               int64
# Penalties             int64
# Positioning           int64
# Reactions             int64
# Short passing         int64
# Shot power            int64
# Sliding tackle        int64
# Sprint speed          int64
# Stamina               int64
# Standing tackle       int64
# Strength              int64
# Vision                int64
# Volleys               int64
# dtype: object

# %%
player_attributes
# Out:
#        Acceleration  Aggression  Agility  Balance  Ball control  Composure  \
# 0                89          63       89       63            93         95
# 1                92          48       90       95            95         96
# 2                94          56       96       82            95         92
# 3                88          78       86       60            91         83
# 4                58          29       52       35            48         70
# 5                79          80       78       80            89         87
# 6                57          38       60       43            42         64
# 7                93          54       93       91            92         87
# 8                60          60       71       69            89         85
# 9                78          50       75       69            85         86
# 10               75          84       79       60            84         80
# 11               76          68       80       75            87         84
# 12               46          23       61       45            23         52
# 13               88          80       90       87            87         86
# 14               75          62       93       94            92         84
# 15               93          65       77       65            87         85
# 16               90          63       86       91            89         90
# 17               68          92       59       64            57         82
# 18               49          38       55       49            28         70
# 19               88          48       91       85            93         84
# 20               43          34       67       49            16         55
# 21               87          69       90       80            86         86
# 22               77          57       90       86            92         83
# 23               95          43       77       70            82         84
# 24               62          82       60       52            75         84
# 25               72          82       58       53            71         86
# 26               62          86       63       58            76         82
# 27               62          66       64       58            77         91
# 28               75          48       83       70            90         78
# 29               65          31       55       54            34         61
# ...             ...         ...      ...      ...           ...        ...
# 17951            40          20       45       52            25         27
# 17952            68          53       63       58            43         42
# 17953            67          53       64       50            44         42
# 17954            69          26       65       74            48         38
# 17955            59          57       62       51            50         46
# 17956            62          41       43       60            27         40
# 17957            56          59       52       55            43         42
# 17958            60          41       46       62            35         35
# 17959            69          52       54       72            45         47
# 17960            43          47       47       65            47         54
# 17961            57          45       44       64            30         43
# 17962            65          43       64       58            33         45
# 17963            57          59       58       70            42         39
# 17964            56          51       51       65            41         35
# 17965            58          54       59       77            43         38
# 17966            59          55       50       79            48         35
# 17967            63          51       57       65            35         38
# 17968            55          47       49       59            30         48
# 17969            62          27       69       71            46         42
# 17970            52          56       60       51            42         38
# 17971            51          33       51       69            44         44
# 17972            60          44       47       54            28         43
# 17973            65          43       57       51            42         35
# 17974            66          40       45       48            34         37
# 17975            25          52       40       52            46         42
# 17976            24          16       38       26            12         23
# 17977            25          44       35       44            22         44
# 17978            66          26       60       77            41         50
# 17979            57          46       58       74            43         45
# 17980            48          52       49       47            32         33
#
#        Crossing  Curve  Dribbling  Finishing   ...     Reactions  \
# 0            85     81         91         94   ...            96
# 1            77     89         97         95   ...            95
# 2            75     81         96         89   ...            88
# 3            77     86         86         94   ...            93
# 4            15     14         30         13   ...            85
# 5            62     77         85         91   ...            91
# 6            17     21         18         13   ...            88
# 7            80     82         93         83   ...            85
# 8            85     85         79         76   ...            86
# 9            68     74         84         91   ...            88
# 10           66     73         61         60   ...            85
# 11           90     83         85         83   ...            88
# 12           14     19         13         14   ...            81
# 13           80     78         90         85   ...            87
# 14           78     79         86         71   ...            88
# 15           87     86         89         87   ...            87
# 16           70     82         89         90   ...            89
# 17           58     60         58         33   ...            82
# 18           13     20         26         15   ...            80
# 19           80     88         92         85   ...            84
# 20           13     13         12         11   ...            84
# 21           82     84         87         88   ...            90
# 22           72     85         90         69   ...            84
# 23           77     78         82         88   ...            87
# 24           44     56         69         39   ...            86
# 25           69     56         67         34   ...            82
# 26           55     49         53         42   ...            85
# 27           64     65         68         55   ...            85
# 28           82     84         86         74   ...            87
# 29           13     11         10         10   ...            85
# ...         ...    ...        ...        ...   ...           ...
# 17951        19     12         13         15   ...            47
# 17952        35     35         42         31   ...            49
# 17953        41     31         42         29   ...            51
# 17954        50     44         46         45   ...            34
# 17955        36     33         51         32   ...            47
# 17956        24     27         29         23   ...            43
# 17957        39     28         39         17   ...            49
# 17958        37     26         21         24   ...            46
# 17959        34     34         43         47   ...            40
# 17960        35     48         47         36   ...            40
# 17961        21     22         32         19   ...            45
# 17962        37     28         38         26   ...            45
# 17963        32     32         41         29   ...            54
# 17964        31     30         44         26   ...            53
# 17965        34     30         43         28   ...            49
# 17966        31     39         46         28   ...            48
# 17967        47     28         54         23   ...            45
# 17968        25     21         26         21   ...            48
# 17969        32     36         51         50   ...            47
# 17970        29     33         29         22   ...            46
# 17971        28     38         47         59   ...            48
# 17972        51     46         48         34   ...            50
# 17973        36     31         48         35   ...            50
# 17974        28     28         29         15   ...            48
# 17975        42     52         44         40   ...            47
# 17976        14     13         12          5   ...            40
# 17977        11     12         11         11   ...            51
# 17978        28     32         37         47   ...            54
# 17979        34     30         41         32   ...            49
# 17980        19     17         23         20   ...            40
#
#        Short passing  Shot power  Sliding tackle  Sprint speed  Stamina  \
# 0                 83          94              23            91       92
# 1                 88          85              26            87       73
# 2                 81          80              33            90       78
# 3                 83          87              38            77       89
# 4                 55          25              11            61       44
# 5                 83          88              19            83       79
# 6                 50          31              13            58       40
# 7                 86          79              22            87       79
# 8                 90          87              69            52       77
# 9                 75          88              18            80       72
# 10                78          79              91            77       84
# 11                90          85              40            75       87
# 12                32          36              16            52       38
# 13                81          84              35            84       85
# 14                92          73              73            71       82
# 15                86          91              52            95       76
# 16                79          88              12            84       74
# 17                59          78              90            78       68
# 18                37          39              11            43       39
# 19                83          82              20            84       83
# 20                29          22              18            60       41
# 21                79          81              11            86       76
# 22                91          75              62            68       75
# 23                77          81              36            96       79
# 24                79          74              88            72       73
# 25                75          79              90            78       74
# 26                79          67              89            67       67
# 27                80          71              90            65       66
# 28                89          70              19            68       69
# 29                50          23              18            63       41
# ...              ...         ...             ...           ...      ...
# 17951             26          25              16            42       33
# 17952             59          49              44            68       61
# 17953             54          49              45            65       60
# 17954             43          46              25            57       48
# 17955             55          54              50            49       40
# 17956             29          35              47            55       57
# 17957             45          39              44            52       51
# 17958             36          38              46            56       48
# 17959             51          48              31            68       64
# 17960             55          44              47            62       38
# 17961             36          32              47            54       62
# 17962             26          22              48            63       62
# 17963             55          43              47            49       42
# 17964             55          46              53            51       44
# 17965             52          54              48            64       59
# 17966             53          42              54            58       37
# 17967             27          22              46            54       60
# 17968             26          32              54            63       59
# 17969             42          45              18            65       55
# 17970             39          43              43            55       61
# 17971             46          52              15            56       53
# 17972             40          44              43            58       52
# 17973             47          41              41            64       55
# 17974             30          30              49            60       52
# 17975             54          52              38            22       30
# 17976             19          19              10            32       28
# 17977             12          13              13            25       32
# 17978             42          42              14            51       33
# 17979             49          43              47            58       49
# 17980             31          21              43            49       55
#
#        Standing tackle  Strength  Vision  Volleys
# 0                   31        80      85       88
# 1                   28        59      90       85
# 2                   24        53      80       83
# 3                   45        80      84       88
# 4                   10        83      70       11
# 5                   42        84      78       87
# 6                   21        64      68       13
# 7                   27        65      86       79
# 8                   82        74      88       82
# 9                   22        85      70       88
# 10                  89        81      63       66
# 11                  51        73      90       82
# 12                  18        70      44       12
# 13                  39        72      83       83
# 14                  80        58      90       74
# 15                  55        80      79       76
# 16                  20        74      83       85
# 17                  92        91      50       45
# 18                  11        69      50       17
# 19                  20        65      84       88
# 20                  12        78      55       13
# 21                  22        61      76       87
# 22                  64        59      86       90
# 23                  25        77      77       86
# 24                  88        85      74       58
# 25                  91        91      76       53
# 26                  86        80      52       47
# 27                  92        85      79       60
# 28                  16        57      92       77
# 29                  10        43      30       11
# ...                ...       ...     ...      ...
# 17951               15        58      20       14
# 17952               36        58      42       32
# 17953               39        49      45       38
# 17954               25        51      42       37
# 17955               44        52      47       28
# 17956               52        63      32       20
# 17957               46        36      38       28
# 17958               48        57      32       21
# 17959               33        58      47       41
# 17960               38        49      53       42
# 17961               52        45      27       20
# 17962               46        60      32       26
# 17963               45        46      47       30
# 17964               44        50      51       31
# 17965               44        31      40       37
# 17966               44        42      51       31
# 17967               46        63      32       23
# 17968               51        50      32       21
# 17969               20        41      47       36
# 17970               46        68      31       19
# 17971               13        61      48       35
# 17972               48        48      40       33
# 17973               39        40      40       33
# 17974               52        42      28       24
# 17975               36        37      43       34
# 17976               11        50      26        6
# 17977               12        47      17       12
# 17978               17        32      37       33
# 17979               48        46      51       25
# 17980               44        67      22       19
#
# [17981 rows x 35 columns]

# %%
player_attributes.head(10)
# Out:
#    Acceleration  Aggression  Agility  Balance  Ball control  Composure  \
# 0            89          63       89       63            93         95
# 1            92          48       90       95            95         96
# 2            94          56       96       82            95         92
# 3            88          78       86       60            91         83
# 4            58          29       52       35            48         70
# 5            79          80       78       80            89         87
# 6            57          38       60       43            42         64
# 7            93          54       93       91            92         87
# 8            60          60       71       69            89         85
# 9            78          50       75       69            85         86
#
#    Crossing  Curve  Dribbling  Finishing   ...     Reactions  Short passing  \
# 0        85     81         91         94   ...            96             83
# 1        77     89         97         95   ...            95             88
# 2        75     81         96         89   ...            88             81
# 3        77     86         86         94   ...            93             83
# 4        15     14         30         13   ...            85             55
# 5        62     77         85         91   ...            91             83
# 6        17     21         18         13   ...            88             50
# 7        80     82         93         83   ...            85             86
# 8        85     85         79         76   ...            86             90
# 9        68     74         84         91   ...            88             75
#
#    Shot power  Sliding tackle  Sprint speed  Stamina  Standing tackle  \
# 0          94              23            91       92               31
# 1          85              26            87       73               28
# 2          80              33            90       78               24
# 3          87              38            77       89               45
# 4          25              11            61       44               10
# 5          88              19            83       79               42
# 6          31              13            58       40               21
# 7          79              22            87       79               27
# 8          87              69            52       77               82
# 9          88              18            80       72               22
#
#    Strength  Vision  Volleys
# 0        80      85       88
# 1        59      90       85
# 2        53      80       83
# 3        80      84       88
# 4        83      70       11
# 5        84      78       87
# 6        64      68       13
# 7        65      86       79
# 8        74      88       82
# 9        85      70       88
#
# [10 rows x 35 columns]

# %% [markdown]
# Escolhendo variáveis

# %%
print(player_attributes.columns)
# Out:
# Index(['Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball control',
#        'Composure', 'Crossing', 'Curve', 'Dribbling', 'Finishing',
#        'Free kick accuracy', 'GK diving', 'GK handling', 'GK kicking',
#        'GK positioning', 'GK reflexes', 'Heading accuracy', 'ID',
#        'Interceptions', 'Jumping', 'Long passing', 'Long shots', 'Marking',
#        'Penalties', 'Positioning', 'Reactions', 'Short passing', 'Shot power',
#        'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
#        'Strength', 'Vision', 'Volleys'],
#       dtype='object')

# %%
linhas = []
i = 0
while i < len(fifa["Unnamed: 0"]):
    linhas.append(fifa["Unnamed: 0"][i])
    i+=1

coluna = ['Acceleration', 'Aggression', 'Agility', 'Balance',
       'Ball control', 'Composure', 'Crossing', 'Curve', 'Dribbling',
       'Finishing', 'Free kick accuracy', 'GK diving', 'GK handling',
       'GK kicking', 'GK positioning', 'GK reflexes', 'Heading accuracy',
       'Interceptions', 'Jumping', 'Long passing', 'Long shots', 'Marking',
       'Penalties', 'Positioning', 'Reactions', 'Short passing', 'Shot power',
       'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
       'Strength', 'Vision', 'Volleys']

df = player_attributes.loc[linhas, coluna]
df
# Out:
#        Acceleration  Aggression  Agility  Balance  Ball control  Composure  \
# 0                89          63       89       63            93         95
# 1                92          48       90       95            95         96
# 2                94          56       96       82            95         92
# 3                88          78       86       60            91         83
# 4                58          29       52       35            48         70
# 5                79          80       78       80            89         87
# 6                57          38       60       43            42         64
# 7                93          54       93       91            92         87
# 8                60          60       71       69            89         85
# 9                78          50       75       69            85         86
# 10               75          84       79       60            84         80
# 11               76          68       80       75            87         84
# 12               46          23       61       45            23         52
# 13               88          80       90       87            87         86
# 14               75          62       93       94            92         84
# 15               93          65       77       65            87         85
# 16               90          63       86       91            89         90
# 17               68          92       59       64            57         82
# 18               49          38       55       49            28         70
# 19               88          48       91       85            93         84
# 20               43          34       67       49            16         55
# 21               87          69       90       80            86         86
# 22               77          57       90       86            92         83
# 23               95          43       77       70            82         84
# 24               62          82       60       52            75         84
# 25               72          82       58       53            71         86
# 26               62          86       63       58            76         82
# 27               62          66       64       58            77         91
# 28               75          48       83       70            90         78
# 29               65          31       55       54            34         61
# ...             ...         ...      ...      ...           ...        ...
# 17951            40          20       45       52            25         27
# 17952            68          53       63       58            43         42
# 17953            67          53       64       50            44         42
# 17954            69          26       65       74            48         38
# 17955            59          57       62       51            50         46
# 17956            62          41       43       60            27         40
# 17957            56          59       52       55            43         42
# 17958            60          41       46       62            35         35
# 17959            69          52       54       72            45         47
# 17960            43          47       47       65            47         54
# 17961            57          45       44       64            30         43
# 17962            65          43       64       58            33         45
# 17963            57          59       58       70            42         39
# 17964            56          51       51       65            41         35
# 17965            58          54       59       77            43         38
# 17966            59          55       50       79            48         35
# 17967            63          51       57       65            35         38
# 17968            55          47       49       59            30         48
# 17969            62          27       69       71            46         42
# 17970            52          56       60       51            42         38
# 17971            51          33       51       69            44         44
# 17972            60          44       47       54            28         43
# 17973            65          43       57       51            42         35
# 17974            66          40       45       48            34         37
# 17975            25          52       40       52            46         42
# 17976            24          16       38       26            12         23
# 17977            25          44       35       44            22         44
# 17978            66          26       60       77            41         50
# 17979            57          46       58       74            43         45
# 17980            48          52       49       47            32         33
#
#        Crossing  Curve  Dribbling  Finishing   ...     Reactions  \
# 0            85     81         91         94   ...            96
# 1            77     89         97         95   ...            95
# 2            75     81         96         89   ...            88
# 3            77     86         86         94   ...            93
# 4            15     14         30         13   ...            85
# 5            62     77         85         91   ...            91
# 6            17     21         18         13   ...            88
# 7            80     82         93         83   ...            85
# 8            85     85         79         76   ...            86
# 9            68     74         84         91   ...            88
# 10           66     73         61         60   ...            85
# 11           90     83         85         83   ...            88
# 12           14     19         13         14   ...            81
# 13           80     78         90         85   ...            87
# 14           78     79         86         71   ...            88
# 15           87     86         89         87   ...            87
# 16           70     82         89         90   ...            89
# 17           58     60         58         33   ...            82
# 18           13     20         26         15   ...            80
# 19           80     88         92         85   ...            84
# 20           13     13         12         11   ...            84
# 21           82     84         87         88   ...            90
# 22           72     85         90         69   ...            84
# 23           77     78         82         88   ...            87
# 24           44     56         69         39   ...            86
# 25           69     56         67         34   ...            82
# 26           55     49         53         42   ...            85
# 27           64     65         68         55   ...            85
# 28           82     84         86         74   ...            87
# 29           13     11         10         10   ...            85
# ...         ...    ...        ...        ...   ...           ...
# 17951        19     12         13         15   ...            47
# 17952        35     35         42         31   ...            49
# 17953        41     31         42         29   ...            51
# 17954        50     44         46         45   ...            34
# 17955        36     33         51         32   ...            47
# 17956        24     27         29         23   ...            43
# 17957        39     28         39         17   ...            49
# 17958        37     26         21         24   ...            46
# 17959        34     34         43         47   ...            40
# 17960        35     48         47         36   ...            40
# 17961        21     22         32         19   ...            45
# 17962        37     28         38         26   ...            45
# 17963        32     32         41         29   ...            54
# 17964        31     30         44         26   ...            53
# 17965        34     30         43         28   ...            49
# 17966        31     39         46         28   ...            48
# 17967        47     28         54         23   ...            45
# 17968        25     21         26         21   ...            48
# 17969        32     36         51         50   ...            47
# 17970        29     33         29         22   ...            46
# 17971        28     38         47         59   ...            48
# 17972        51     46         48         34   ...            50
# 17973        36     31         48         35   ...            50
# 17974        28     28         29         15   ...            48
# 17975        42     52         44         40   ...            47
# 17976        14     13         12          5   ...            40
# 17977        11     12         11         11   ...            51
# 17978        28     32         37         47   ...            54
# 17979        34     30         41         32   ...            49
# 17980        19     17         23         20   ...            40
#
#        Short passing  Shot power  Sliding tackle  Sprint speed  Stamina  \
# 0                 83          94              23            91       92
# 1                 88          85              26            87       73
# 2                 81          80              33            90       78
# 3                 83          87              38            77       89
# 4                 55          25              11            61       44
# 5                 83          88              19            83       79
# 6                 50          31              13            58       40
# 7                 86          79              22            87       79
# 8                 90          87              69            52       77
# 9                 75          88              18            80       72
# 10                78          79              91            77       84
# 11                90          85              40            75       87
# 12                32          36              16            52       38
# 13                81          84              35            84       85
# 14                92          73              73            71       82
# 15                86          91              52            95       76
# 16                79          88              12            84       74
# 17                59          78              90            78       68
# 18                37          39              11            43       39
# 19                83          82              20            84       83
# 20                29          22              18            60       41
# 21                79          81              11            86       76
# 22                91          75              62            68       75
# 23                77          81              36            96       79
# 24                79          74              88            72       73
# 25                75          79              90            78       74
# 26                79          67              89            67       67
# 27                80          71              90            65       66
# 28                89          70              19            68       69
# 29                50          23              18            63       41
# ...              ...         ...             ...           ...      ...
# 17951             26          25              16            42       33
# 17952             59          49              44            68       61
# 17953             54          49              45            65       60
# 17954             43          46              25            57       48
# 17955             55          54              50            49       40
# 17956             29          35              47            55       57
# 17957             45          39              44            52       51
# 17958             36          38              46            56       48
# 17959             51          48              31            68       64
# 17960             55          44              47            62       38
# 17961             36          32              47            54       62
# 17962             26          22              48            63       62
# 17963             55          43              47            49       42
# 17964             55          46              53            51       44
# 17965             52          54              48            64       59
# 17966             53          42              54            58       37
# 17967             27          22              46            54       60
# 17968             26          32              54            63       59
# 17969             42          45              18            65       55
# 17970             39          43              43            55       61
# 17971             46          52              15            56       53
# 17972             40          44              43            58       52
# 17973             47          41              41            64       55
# 17974             30          30              49            60       52
# 17975             54          52              38            22       30
# 17976             19          19              10            32       28
# 17977             12          13              13            25       32
# 17978             42          42              14            51       33
# 17979             49          43              47            58       49
# 17980             31          21              43            49       55
#
#        Standing tackle  Strength  Vision  Volleys
# 0                   31        80      85       88
# 1                   28        59      90       85
# 2                   24        53      80       83
# 3                   45        80      84       88
# 4                   10        83      70       11
# 5                   42        84      78       87
# 6                   21        64      68       13
# 7                   27        65      86       79
# 8                   82        74      88       82
# 9                   22        85      70       88
# 10                  89        81      63       66
# 11                  51        73      90       82
# 12                  18        70      44       12
# 13                  39        72      83       83
# 14                  80        58      90       74
# 15                  55        80      79       76
# 16                  20        74      83       85
# 17                  92        91      50       45
# 18                  11        69      50       17
# 19                  20        65      84       88
# 20                  12        78      55       13
# 21                  22        61      76       87
# 22                  64        59      86       90
# 23                  25        77      77       86
# 24                  88        85      74       58
# 25                  91        91      76       53
# 26                  86        80      52       47
# 27                  92        85      79       60
# 28                  16        57      92       77
# 29                  10        43      30       11
# ...                ...       ...     ...      ...
# 17951               15        58      20       14
# 17952               36        58      42       32
# 17953               39        49      45       38
# 17954               25        51      42       37
# 17955               44        52      47       28
# 17956               52        63      32       20
# 17957               46        36      38       28
# 17958               48        57      32       21
# 17959               33        58      47       41
# 17960               38        49      53       42
# 17961               52        45      27       20
# 17962               46        60      32       26
# 17963               45        46      47       30
# 17964               44        50      51       31
# 17965               44        31      40       37
# 17966               44        42      51       31
# 17967               46        63      32       23
# 17968               51        50      32       21
# 17969               20        41      47       36
# 17970               46        68      31       19
# 17971               13        61      48       35
# 17972               48        48      40       33
# 17973               39        40      40       33
# 17974               52        42      28       24
# 17975               36        37      43       34
# 17976               11        50      26        6
# 17977               12        47      17       12
# 17978               17        32      37       33
# 17979               48        46      51       25
# 17980               44        67      22       19
#
# [17981 rows x 34 columns]

# %%
corr = df.corr()

# %%
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]), #tamanho da fonte das variáveis
            
            dict(selector="td",
                 props=[('padding', "0em 0em")]), #tamanho dos retângulos  
            
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]), #tamanho da fonte das variáveis quando passsar o mouse sobre elas
            
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')]) #tamanho dos valores quando passar o mouse sobre eles
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5 th {
#           font-size: 7pt;
#     }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5 td {
#           padding: 0em 0em;
#     }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5 th:hover {
#           font-size: 12pt;
#     }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col0 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col1 {
#             background-color:  #eaf0f7;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col2 {
#             background-color:  #7099cb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col3 {
#             background-color:  #86a8d3;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col4 {
#             background-color:  #8dadd5;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col5 {
#             background-color:  #c0d2e8;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col6 {
#             background-color:  #90afd6;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col7 {
#             background-color:  #9cb8db;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col8 {
#             background-color:  #7da2cf;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col9 {
#             background-color:  #9cb8db;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col10 {
#             background-color:  #b3c9e3;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col11 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col12 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col13 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col14 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col15 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col16 {
#             background-color:  #d8e3f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col17 {
#             background-color:  #fae6ea;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col18 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col19 {
#             background-color:  #c1d3e8;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col20 {
#             background-color:  #a3bddd;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col21 {
#             background-color:  #f9e2e6;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col22 {
#             background-color:  #adc4e1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col23 {
#             background-color:  #8cacd5;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col24 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col25 {
#             background-color:  #a4bede;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col26 {
#             background-color:  #aac2e0;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col27 {
#             background-color:  #fae6ea;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col28 {
#             background-color:  #5686c1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col29 {
#             background-color:  #9bb7da;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col30 {
#             background-color:  #fae6ea;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col31 {
#             background-color:  #eb9dac;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col32 {
#             background-color:  #bccfe7;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row0_col33 {
#             background-color:  #a3bddd;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row1_col0 {
#             background-color:  #ecf2f8;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row1_col1 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row1_col2 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row1_col3 {
#             background-color:  #fbeaed;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row1_col4 {
#             background-color:  #acc3e1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row1_col5 {
#             background-color:  #a2bcdd;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row1_col6 {
#             background-color:  #bbcee6;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row1_col7 {
#             background-color:  #cddbed;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row1_col8 {
#             background-color:  #c5d5ea;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row1_col9 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row1_col10 {
#             background-color:  #cbdaec;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_e35d22dfc7a5row1_col11 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_1187f1f8_e6bc_11e8_ae96_

# %%
plt.figure(figsize= (16, 16))
sns.heatmap(corr, linewidth=0.5);

# %% [markdown]
# # Distribuição Value

# %%
fifa.Value.describe()
# Out:
# count    1.772500e+04
# mean     2.419841e+06
# std      5.384761e+06
# min      1.000000e+04
# 25%      3.250000e+05
# 50%      7.000000e+05
# 75%      2.100000e+06
# max      1.230000e+08
# Name: Value, dtype: float64

# %%
value_min = fifa.Value.min()
value_max = fifa.Value.max()

print('O jogador mais barato do jogo custa: €{:.2f}'.format(value_min))
print('O jogador mais caro do jogo custa: €{:.2f}'.format(value_max))
# Out:
# O jogador mais barato do jogo custa: €10000.00
# O jogador mais caro do jogo custa: €123000000.00

# %%
value_limpo = fifa.Value.dropna()

# %%
values=[]
for dados_value in value_limpo:
    values.append(dados_value)
plt.hist(np.log(values), density=True, bins= 40);
plt.ylabel('Densidade');
plt.xlabel('Values');

# %% [markdown]
# Percebe-se que há poucos jogadores que são classificados com alto valor de mercado. Esse critério se relaciona bastante com a realidade do futebol, em que tornar-se um jogador renomado, reconhecido e valorizado no mercado é muito raro.

# %%
stats.probplot(np.log(values), dist='norm', plot=plt);

# %% [markdown]
# Dessa forma, baseando-se no histograma analisado acima, era de se esperar que a distribuição de valores de mercado no mundo do futebol não se encaixa em uma curva normal.

# %% [markdown]
# # Distribuição Overall

# %%
fifa_limpo.Overall.describe()
# Out:
# count    17981.000000
# mean        66.247984
# std          6.987965
# min         46.000000
# 25%         62.000000
# 50%         66.000000
# 75%         71.000000
# max         94.000000
# Name: Overall, dtype: float64

# %%
media, dp = norm.fit(fifa.Overall)

print('Média: {0}'.format(media))
print('Desvio Padrão: {0}'.format(dp))
# Out:
# Média: 66.24798398309326
# Desvio Padrão: 6.98777102178669

# %%
overall_min = 46
overall_max = 94

print('Overall mais baixo do jogo: {0}'.format(overall_min))
print('Overall mais alto do jogo: {0}'.format(overall_max))
# Out:
# Overall mais baixo do jogo: 46
# Overall mais alto do jogo: 94

# %%
overalls=[]
for dados_overall in fifa.Overall:
    overalls.append(dados_overall)
plt.hist(overalls, density=True, bins= 40);
plt.ylabel('Densidade');
plt.xlabel('Overall');

# %%
#Verificar graficamente se a distribuição normal é um modelo adequado para o overall dos jogadores

stats.probplot(overalls, dist='norm', plot=plt);

# %% [markdown]
# Percebe-se que a distribuição normal pode ser considerada aceitável como modelo para o overall dos jogadores, pois grande parte dos pontos se encontram sobre a linha vermelha (diagonal).

# %%
x = np.linspace(overall_min-5, overall_max+5, 1000)
y = norm.pdf(x, loc=media , scale=dp)
plt.plot(x, y)
plt.grid(True)
plt.show()

# %%
#plotar

plt.hist(overalls, density=True, bins= 30)
plt.axis([overall_min-5, overall_max+5, 0, 0.09])
plt.ylabel('Densidade')
plt.xlabel('Overall')
plt.plot(x, y)
plt.show()

# %% [markdown]
# # Value x Overall

# %%
fifa.head()
# Out:
#    Unnamed: 0               Name  Age  \
# 0           0  Cristiano Ronaldo   32
# 1           1           L. Messi   30
# 2           2             Neymar   25
# 3           3          L. Suárez   30
# 4           4           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# 4  https://cdn.sofifa.org/flags/21.png       92         92
#
#                   Club                                   Club Logo  ...   \
# 0       Real Madrid CF  https://cdn.sofifa.org/24/18/teams/243.png  ...
# 1         FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/24/18/teams/73.png  ...
# 3         FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png  ...
# 4     FC Bayern Munich   https://cdn.sofifa.org/24/18/teams/21.png  ...
#
#      RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  61.0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  57.0  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  59.0  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  64.0  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 75 columns]

# %%
fifa.dtypes
# Out:
# Unnamed: 0               int64
# Name                    object
# Age                      int64
# Photo                   object
# Nationality             object
# Flag                    object
# Overall                  int64
# Potential                int64
# Club                    object
# Club Logo               object
# Value                  float64
# Wage                    object
# Special                  int64
# Acceleration            object
# Aggression              object
# Agility                 object
# Balance                 object
# Ball control            object
# Composure               object
# Crossing                object
# Curve                   object
# Dribbling               object
# Finishing               object
# Free kick accuracy      object
# GK diving               object
# GK handling             object
# GK kicking              object
# GK positioning          object
# GK reflexes             object
# Heading accuracy        object
#                         ...
# Vision                  object
# Volleys                 object
# CAM                    float64
# CB                     float64
# CDM                    float64
# CF                     float64
# CM                     float64
# ID                       int64
# LAM                    float64
# LB                     float64
# LCB                    float64
# LCM                    float64
# LDM                    float64
# LF                     float64
# LM                     float64
# LS                     float64
# LW                     float64
# LWB                    float64
# Preferred Positions     object
# RAM                    float64
# RB                     float64
# RCB                    float64
# RCM                    float64
# RDM                    float64
# RF                     float64
# RM                     float64
# RS                     float64
# RW                     float64
# RWB                    float64
# ST                     float64
# Length: 75, dtype: object

# %%
linhas = linhas
colunas = ["Overall", "Value"]

ovrl_value = fifa.loc[linhas, colunas]

# %%
ovrl_value
# Out:
#        Overall        Value
# 0           94   95500000.0
# 1           93  105000000.0
# 2           92  123000000.0
# 3           92   97000000.0
# 4           92   61000000.0
# 5           91   92000000.0
# 6           90   64500000.0
# 7           90   90500000.0
# 8           90   79000000.0
# 9           90   77000000.0
# 10          90   52000000.0
# 11          89   83000000.0
# 12          89   59000000.0
# 13          89   67500000.0
# 14          89   57000000.0
# 15          89   69500000.0
# 16          89   66500000.0
# 17          89   38000000.0
# 18          89    4500000.0
# 19          88   79000000.0
# 20          88   57000000.0
# 21          88   75000000.0
# 22          88   70500000.0
# 23          88   61000000.0
# 24          88   44000000.0
# 25          88   48000000.0
# 26          88   40000000.0
# 27          88   48000000.0
# 28          88   60000000.0
# 29          88   38000000.0
# ...        ...          ...
# 17951       48      40000.0
# 17952       48      60000.0
# 17953       48      60000.0
# 17954       48      60000.0
# 17955       48      60000.0
# 17956       48      50000.0
# 17957       47      50000.0
# 17958       47      40000.0
# 17959       47      60000.0
# 17960       47      70000.0
# 17961       47      60000.0
# 17962       47      50000.0
# 17963       47      50000.0
# 17964       47      60000.0
# 17965       47      60000.0
# 17966       47      60000.0
# 17967       47      60000.0
# 17968       47      60000.0
# 17969       47      60000.0
# 17970       47      40000.0
# 17971       47      60000.0
# 17972       47      60000.0
# 17973       46      50000.0
# 17974       46      40000.0
# 17975       46      30000.0
# 17976       46      50000.0
# 17977       46          NaN
# 17978       46      60000.0
# 17979       46      60000.0
# 17980       46      50000.0
#
# [17981 rows x 2 columns]

# %%
ovrl_value = ovrl_value.dropna()

# %%
scatter = ovrl_value.plot.scatter(x= "Overall", y = "Value")
scatter

# %%
def reta(dados_x, dados_y):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()
 
    print('Ajuste linear entre X3 e X4:')
    print('Coeficiente linear:', b)
    print('Coeficiente angular:', a)
 
    fig = plt.figure(figsize=(8, 6))
    plt.scatter(dados_x, dados_y, c='red', alpha=0.8)
    plt.title('Gráfico de Correlação')
    plt.axis([overall_min-10, overall_max+10, -1000, 130000000])
    plt.xlabel('Overall')
    plt.ylabel('Value')
 
    plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color='blue')
 
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
print (reta(ovrl_value['Overall'],ovrl_value['Value']))
# Out:
# Ajuste linear entre X3 e X4:
# Coeficiente linear: -29748061.320731457
# Coeficiente angular: 485665.84831118427
# None

# %%
ovrl_value.corr()
# Out:
#           Overall     Value
# Overall  1.000000  0.631265
# Value    0.631265  1.000000

# %% [markdown]
# # Potencial x Idade

# %%
colunas = ["Age", "Overall", "Potential"]

pot_age_ovrl = fifa.loc[linhas, colunas]

#corr_pot_age = fifa.corr('Potential', 'Age')
pot_age_ovrl
# Out:
#        Age  Overall  Potential
# 0       32       94         94
# 1       30       93         93
# 2       25       92         94
# 3       30       92         92
# 4       31       92         92
# 5       28       91         91
# 6       26       90         92
# 7       26       90         91
# 8       27       90         90
# 9       29       90         90
# 10      31       90         90
# 11      26       89         92
# 12      25       89         92
# 13      28       89         89
# 14      31       89         89
# 15      27       89         89
# 16      29       89         89
# 17      32       89         89
# 18      39       89         89
# 19      23       88         93
# 20      24       88         93
# 21      26       88         91
# 22      26       88         90
# 23      28       88         88
# 24      30       88         88
# 25      28       88         88
# 26      31       88         88
# 27      28       88         88
# 28      28       88         88
# 29      30       88         88
# ...    ...      ...        ...
# 17951   21       48         58
# 17952   17       48         68
# 17953   18       48         67
# 17954   19       48         64
# 17955   18       48         63
# 17956   17       48         64
# 17957   17       47         61
# 17958   17       47         59
# 17959   18       47         64
# 17960   18       47         69
# 17961   17       47         73
# 17962   18       47         63
# 17963   19       47         58
# 17964   18       47         67
# 17965   18       47         61
# 17966   18       47         67
# 17967   19       47         67
# 17968   17       47         68
# 17969   18       47         67
# 17970   19       47         56
# 17971   18       47         65
# 17972   19       47         63
# 17973   18       46         58
# 17974   18       46         56
# 17975   28       46         46
# 17976   17       46         63
# 17977   47       46         46
# 17978   17       46         61
# 17979   18       46         64
# 17980   18       46         64
#
# [17981 rows x 3 columns]

# %%
#potencial = overall - potential

potencial = []
for dado1 in pot_age_ovrl.Potential:
    potencial.append(dado1)

overall = []
for dado2 in pot_age_ovrl.Overall:
    overall.append(dado2)
    

potencial_overall = []
i = 0
j = 0
while i < len(potencial):
    while j < len(overall):
        valor = potencial[i] - overall[j]
        potencial_overall.append(valor)
        j+=1
        i+=1

# %%
s = pd.Series(potencial_overall)

# %%
pot_age_ovrl['Evolução'] = s

# %%
pot_age_ovrl
# Out:
#        Age  Overall  Potential  Evolução
# 0       32       94         94         0
# 1       30       93         93         0
# 2       25       92         94         2
# 3       30       92         92         0
# 4       31       92         92         0
# 5       28       91         91         0
# 6       26       90         92         2
# 7       26       90         91         1
# 8       27       90         90         0
# 9       29       90         90         0
# 10      31       90         90         0
# 11      26       89         92         3
# 12      25       89         92         3
# 13      28       89         89         0
# 14      31       89         89         0
# 15      27       89         89         0
# 16      29       89         89         0
# 17      32       89         89         0
# 18      39       89         89         0
# 19      23       88         93         5
# 20      24       88         93         5
# 21      26       88         91         3
# 22      26       88         90         2
# 23      28       88         88         0
# 24      30       88         88         0
# 25      28       88         88         0
# 26      31       88         88         0
# 27      28       88         88         0
# 28      28       88         88         0
# 29      30       88         88         0
# ...    ...      ...        ...       ...
# 17951   21       48         58        10
# 17952   17       48         68        20
# 17953   18       48         67        19
# 17954   19       48         64        16
# 17955   18       48         63        15
# 17956   17       48         64        16
# 17957   17       47         61        14
# 17958   17       47         59        12
# 17959   18       47         64        17
# 17960   18       47         69        22
# 17961   17       47         73        26
# 17962   18       47         63        16
# 17963   19       47         58        11
# 17964   18       47         67        20
# 17965   18       47         61        14
# 17966   18       47         67        20
# 17967   19       47         67        20
# 17968   17       47         68        21
# 17969   18       47         67        20
# 17970   19       47         56         9
# 17971   18       47         65        18
# 17972   19       47         63        16
# 17973   18       46         58        12
# 17974   18       46         56        10
# 17975   28       46         46         0
# 17976   17       46         63        17
# 17977   47       46         46         0
# 17978   17       46         61        15
# 17979   18       46         64        18
# 17980   18       46         64        18
#
# [17981 rows x 4 columns]

# %%
corr_potencial_idade =  pot_age_ovrl.corr()

# %%
corr_potencial_idade
# Out:
#                 Age   Overall  Potential  Evolução
# Age        1.000000  0.459765  -0.218264 -0.862277
# Overall    0.459765  1.000000   0.683474 -0.534526
# Potential -0.218264  0.683474   1.000000  0.251605
# Evolução  -0.862277 -0.534526   0.251605  1.000000

# %%
colunas = ["Age", "Evolução"]



pot_age = pot_age_ovrl.loc[linhas, colunas]

# %%
pot_age
# Out:
#        Age  Evolução
# 0       32         0
# 1       30         0
# 2       25         2
# 3       30         0
# 4       31         0
# 5       28         0
# 6       26         2
# 7       26         1
# 8       27         0
# 9       29         0
# 10      31         0
# 11      26         3
# 12      25         3
# 13      28         0
# 14      31         0
# 15      27         0
# 16      29         0
# 17      32         0
# 18      39         0
# 19      23         5
# 20      24         5
# 21      26         3
# 22      26         2
# 23      28         0
# 24      30         0
# 25      28         0
# 26      31         0
# 27      28         0
# 28      28         0
# 29      30         0
# ...    ...       ...
# 17951   21        10
# 17952   17        20
# 17953   18        19
# 17954   19        16
# 17955   18        15
# 17956   17        16
# 17957   17        14
# 17958   17        12
# 17959   18        17
# 17960   18        22
# 17961   17        26
# 17962   18        16
# 17963   19        11
# 17964   18        20
# 17965   18        14
# 17966   18        20
# 17967   19        20
# 17968   17        21
# 17969   18        20
# 17970   19         9
# 17971   18        18
# 17972   19        16
# 17973   18        12
# 17974   18        10
# 17975   28         0
# 17976   17        17
# 17977   47         0
# 17978   17        15
# 17979   18        18
# 17980   18        18
#
# [17981 rows x 2 columns]

# %%
def reta(dados_x, dados_y):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()
 
    print('Ajuste linear entre X3 e X4:')
    print('Coeficiente linear:', b)
    print('Coeficiente angular:', a)
 
    fig = plt.figure(figsize=(8, 6))
    plt.scatter(dados_x, dados_y, c='red', alpha=0.8)
    plt.title('Gráfico de Correlação')
    plt.axis([idade_min-5, idade_max+5, -5, 30])
    plt.xlabel('Idade')
    plt.ylabel('Potencial')
 
    plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color='blue')
 
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
print (reta(pot_age['Age'], pot_age['Evolução']))
# Out:
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 29.708323020232875
# Coeficiente angular: -0.9849252776380094
# None

# %%
pot_age.corr()
# Out:
#                Age  Evolução
# Age       1.000000 -0.862277
# Evolução -0.862277  1.000000

# %% [markdown]
# Percebe-se que a idade e o potencial que o jogador tem para aprimorar suas habilidades se correlacionam de modo que os jogadores mais jovens são mais aptos a se desenvolverem no jogo, enquanto os mais velhos não possuem tal potencial.

# %% [markdown]
# # IDADE X OVERALL

# %%
linhas = linhas
colunas = ["Age", "Overall"]
age_ovrl = fifa.loc[linhas, colunas]

# %%
age_ovrl
# Out:
#        Age  Overall
# 0       32       94
# 1       30       93
# 2       25       92
# 3       30       92
# 4       31       92
# 5       28       91
# 6       26       90
# 7       26       90
# 8       27       90
# 9       29       90
# 10      31       90
# 11      26       89
# 12      25       89
# 13      28       89
# 14      31       89
# 15      27       89
# 16      29       89
# 17      32       89
# 18      39       89
# 19      23       88
# 20      24       88
# 21      26       88
# 22      26       88
# 23      28       88
# 24      30       88
# 25      28       88
# 26      31       88
# 27      28       88
# 28      28       88
# 29      30       88
# ...    ...      ...
# 17951   21       48
# 17952   17       48
# 17953   18       48
# 17954   19       48
# 17955   18       48
# 17956   17       48
# 17957   17       47
# 17958   17       47
# 17959   18       47
# 17960   18       47
# 17961   17       47
# 17962   18       47
# 17963   19       47
# 17964   18       47
# 17965   18       47
# 17966   18       47
# 17967   19       47
# 17968   17       47
# 17969   18       47
# 17970   19       47
# 17971   18       47
# 17972   19       47
# 17973   18       46
# 17974   18       46
# 17975   28       46
# 17976   17       46
# 17977   47       46
# 17978   17       46
# 17979   18       46
# 17980   18       46
#
# [17981 rows x 2 columns]

# %%
def reta(dados_x, dados_y):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()
 
    print('Ajuste linear entre X3 e X4:')
    print('Coeficiente linear:', b)
    print('Coeficiente angular:', a)
 
    fig = plt.figure(figsize=(8, 6))
    plt.scatter(dados_x, dados_y, c='red', alpha=0.8)
    plt.title('Gráfico de Correlação')
    plt.axis([idade_min-5, idade_max+5, 30, 100])
    plt.xlabel('Idade')
    plt.ylabel('Overall')
 
    plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color='blue')
 
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
print (reta(age_ovrl['Age'], age_ovrl['Overall']))
# Out:
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 48.74036569110732
# Coeficiente angular: 0.6962790838535429
# None

# %%
corr_age_ovrl = age_ovrl.corr()
corr_age_ovrl
# Out:
#               Age   Overall
# Age      1.000000  0.459765
# Overall  0.459765  1.000000

# %% [markdown]
# Percebe-se que a idade não se correlaciona com as qualidades do jogador (overall). Assim, é viável afirmar que há jogadores jovens tão bons quanto jogadores mais velhos.

# %% [markdown]
# # Value x Age

# %%
linhas = linhas
colunas = ["Value", "Age"]

value_age = fifa.loc[linhas, colunas]

# %%
value_age
# Out:
#              Value  Age
# 0       95500000.0   32
# 1      105000000.0   30
# 2      123000000.0   25
# 3       97000000.0   30
# 4       61000000.0   31
# 5       92000000.0   28
# 6       64500000.0   26
# 7       90500000.0   26
# 8       79000000.0   27
# 9       77000000.0   29
# 10      52000000.0   31
# 11      83000000.0   26
# 12      59000000.0   25
# 13      67500000.0   28
# 14      57000000.0   31
# 15      69500000.0   27
# 16      66500000.0   29
# 17      38000000.0   32
# 18       4500000.0   39
# 19      79000000.0   23
# 20      57000000.0   24
# 21      75000000.0   26
# 22      70500000.0   26
# 23      61000000.0   28
# 24      44000000.0   30
# 25      48000000.0   28
# 26      40000000.0   31
# 27      48000000.0   28
# 28      60000000.0   28
# 29      38000000.0   30
# ...            ...  ...
# 17951      40000.0   21
# 17952      60000.0   17
# 17953      60000.0   18
# 17954      60000.0   19
# 17955      60000.0   18
# 17956      50000.0   17
# 17957      50000.0   17
# 17958      40000.0   17
# 17959      60000.0   18
# 17960      70000.0   18
# 17961      60000.0   17
# 17962      50000.0   18
# 17963      50000.0   19
# 17964      60000.0   18
# 17965      60000.0   18
# 17966      60000.0   18
# 17967      60000.0   19
# 17968      60000.0   17
# 17969      60000.0   18
# 17970      40000.0   19
# 17971      60000.0   18
# 17972      60000.0   19
# 17973      50000.0   18
# 17974      40000.0   18
# 17975      30000.0   28
# 17976      50000.0   17
# 17977          NaN   47
# 17978      60000.0   17
# 17979      60000.0   18
# 17980      50000.0   18
#
# [17981 rows x 2 columns]

# %%
corr_value_age = value_age.corr()
corr_value_age
# Out:
#           Value       Age
# Value  1.000000  0.084375
# Age    0.084375  1.000000

# %% [markdown]
# # Player Value x Skills

# %%
print(fifa.columns)
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball control',
#        'Composure', 'Crossing', 'Curve', 'Dribbling', 'Finishing',
#        'Free kick accuracy', 'GK diving', 'GK handling', 'GK kicking',
#        'GK positioning', 'GK reflexes', 'Heading accuracy', 'Interceptions',
#        'Jumping', 'Long passing', 'Long shots', 'Marking', 'Penalties',
#        'Positioning', 'Reactions', 'Short passing', 'Shot power',
#        'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
#        'Strength', 'Vision', 'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'ID',
#        'LAM', 'LB', 'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB',
#        'Preferred Positions', 'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM',
#        'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
linhas = linhas
colunas = ['Value', 'Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball control',
       'Composure', 'Crossing', 'Curve', 'Dribbling', 'Finishing',
       'Free kick accuracy', 'GK diving', 'GK handling', 'GK kicking',
       'GK positioning', 'GK reflexes', 'Heading accuracy', 'Interceptions',
       'Jumping', 'Long passing', 'Long shots', 'Marking', 'Penalties',
       'Positioning', 'Reactions', 'Short passing', 'Shot power',
       'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
       'Strength', 'Vision', 'Volleys']
value_skills = fifa.loc[linhas, colunas]

# %%
value_skills.head()
# Out:
#          Value Acceleration Aggression Agility Balance Ball control Composure  \
# 0   95500000.0           89         63      89      63           93        95
# 1  105000000.0           92         48      90      95           95        96
# 2  123000000.0           94         56      96      82           95        92
# 3   97000000.0           88         78      86      60           91        83
# 4   61000000.0           58         29      52      35           48        70
#
#   Crossing Curve Dribbling   ...   Reactions Short passing Shot power  \
# 0       85    81        91   ...          96            83         94
# 1       77    89        97   ...          95            88         85
# 2       75    81        96   ...          88            81         80
# 3       77    86        86   ...          93            83         87
# 4       15    14        30   ...          85            55         25
#
#   Sliding tackle Sprint speed Stamina Standing tackle Strength Vision Volleys
# 0             23           91      92              31       80     85      88
# 1             26           87      73              28       59     90      85
# 2             33           90      78              24       53     80      83
# 3             38           77      89              45       80     84      88
# 4             11           61      44              10       83     70      11
#
# [5 rows x 35 columns]

# %% [markdown]
# # Value x Preferred Position

# %%
linhas = linhas
colunas = ["Preferred Positions", "Value"]

pos_value = fifa.loc[linhas, colunas]

# %%
pos_value = pos_value.dropna()

# %%
posicao = []
for posicoes in fifa["Preferred Positions"]:
    uma_posicao = posicoes.split(" ")
    posicao.append(uma_posicao[0])


posicao = pd.Series(posicao)

# %%
pos_value["Preferred Position"] = posicao

# %%
pos_value
# Out:
#       Preferred Positions        Value Preferred Position
# 0                  ST LW    95500000.0                 ST
# 1                     RW   105000000.0                 RW
# 2                     LW   123000000.0                 LW
# 3                     ST    97000000.0                 ST
# 4                     GK    61000000.0                 GK
# 5                     ST    92000000.0                 ST
# 6                     GK    64500000.0                 GK
# 7                     LW    90500000.0                 LW
# 8                 CDM CM    79000000.0                CDM
# 9                     ST    77000000.0                 ST
# 10                    CB    52000000.0                 CB
# 11             RM CM CAM    83000000.0                 RM
# 12                    GK    59000000.0                 GK
# 13           RM LW ST LM    67500000.0                 RM
# 14                CDM CM    57000000.0                CDM
# 15                    RW    69500000.0                 RW
# 16                    ST    66500000.0                 ST
# 17                    CB    38000000.0                 CB
# 18                    GK     4500000.0                 GK
# 19                ST CAM    79000000.0                 ST
# 20                    GK    57000000.0                 GK
# 21              LW RW ST    75000000.0                 LW
# 22            CDM CAM CM    70500000.0                CDM
# 23                    ST    61000000.0                 ST
# 24                    CB    44000000.0                 CB
# 25                    CB    48000000.0                 CB
# 26                    CB    40000000.0                 CB
# 27                    CB    48000000.0                 CB
# 28                RW CAM    60000000.0                 RW
# 29                    GK    38000000.0                 GK
# ...                   ...          ...                ...
# 17950              LM LB       60000.0                 LM
# 17951                 GK       40000.0                 GK
# 17952                 CM       60000.0                 CM
# 17953              RB CM       60000.0                 RB
# 17954                 LM       60000.0                 LM
# 17955                 CM       60000.0                 CM
# 17956                 CB       50000.0                 CB
# 17957                 RB       50000.0                 RB
# 17958              CB RB       40000.0                 CB
# 17959             CAM ST       60000.0                CAM
# 17960                CAM       70000.0                CAM
# 17961                 CB       60000.0                 CB
# 17962              CB LB       50000.0                 CB
# 17963                 CM       50000.0                 CM
# 17964                 CM       60000.0                 CM
# 17965                 CM       60000.0                 CM
# 17966                 CM       60000.0                 CM
# 17967                 RB       60000.0                 RB
# 17968                 CB       60000.0                 CB
# 17969                 ST       60000.0                 ST
# 17970                 CB       40000.0                 CB
# 17971           ST RM LM       60000.0                 ST
# 17972       CB LW LWB LB       60000.0                 CB
# 17973                 CM       50000.0                 CM
# 17974                 CB       40000.0                 CB
# 17975                 CM       30000.0                 CM
# 17976                 GK       50000.0                 GK
# 17978                 ST       60000.0                 ST
# 17979                 CM       60000.0                 CM
# 17980              ST CB       50000.0                 ST
#
# [17725 rows x 3 columns]

# %%
Forward = ['CF', 'LF', 'LS', 'LW', 'RF', 'RS', 'RW', 'ST']
Midfield = ['CAM', 'CDM', 'CM', 'LAM', 'LCM', 'LDM', 'LM', 'RAM', 'RCB', 'RCM', 'RDM', 'RM']
Backward = ['CB', 'LB', 'LCB', 'LWB', 'RB', 'RCB', 'RWB']
Goalkeeper = ['GK']

local = []
for pos in pos_value["Preferred Position"]:
    if pos in Forward:
        local.append("Forward")
    elif pos in Midfield:
        local.append("Midfield")
    elif pos in Backward:
        local.append("Backward")
    elif pos in Goalkeeper:
        local.append("Goalkeaper")

# %%
pos_value["Preferred Position"].value_counts()
# Out:
# CB     2658
# ST     2261
# GK     1984
# CM     1952
# CDM    1371
# RM     1327
# LM     1312
# LB     1292
# RB     1186
# CAM    1108
# RW      426
# LW      422
# CF      199
# LWB     119
# RWB     108
# Name: Preferred Position, dtype: int64

# %%
pos_value["Região"].value_counts()
# Out:
# Midfield      6971
# Backward      5285
# Forward       3263
# Goalkeaper    1951
# Name: Região, dtype: int64

# %%
regiao = pd.Series(local)

# %%
pos_value["Região"] = regiao

# %%
regiao
# Out:
# 0           Forward
# 1           Forward
# 2           Forward
# 3           Forward
# 4        Goalkeaper
# 5           Forward
# 6        Goalkeaper
# 7           Forward
# 8          Midfield
# 9           Forward
# 10         Backward
# 11         Midfield
# 12       Goalkeaper
# 13         Midfield
# 14         Midfield
# 15          Forward
# 16          Forward
# 17         Backward
# 18       Goalkeaper
# 19          Forward
# 20       Goalkeaper
# 21          Forward
# 22         Midfield
# 23          Forward
# 24         Backward
# 25         Backward
# 26         Backward
# 27         Backward
# 28          Forward
# 29       Goalkeaper
#             ...
# 17695      Midfield
# 17696    Goalkeaper
# 17697      Midfield
# 17698      Backward
# 17699      Midfield
# 17700      Midfield
# 17701      Backward
# 17702      Backward
# 17703      Backward
# 17704      Midfield
# 17705      Midfield
# 17706      Backward
# 17707      Backward
# 17708      Midfield
# 17709      Midfield
# 17710      Midfield
# 17711      Midfield
# 17712      Backward
# 17713      Backward
# 17714       Forward
# 17715      Backward
# 17716       Forward
# 17717      Backward
# 17718      Midfield
# 17719      Backward
# 17720      Midfield
# 17721    Goalkeaper
# 17722       Forward
# 17723      Midfield
# 17724       Forward
# Length: 17725, dtype: object

# %%
pos_value
# Out:
#       Preferred Positions        Value Preferred Position      Região
# 0                  ST LW    95500000.0                 ST     Forward
# 1                     RW   105000000.0                 RW     Forward
# 2                     LW   123000000.0                 LW     Forward
# 3                     ST    97000000.0                 ST     Forward
# 4                     GK    61000000.0                 GK  Goalkeaper
# 5                     ST    92000000.0                 ST     Forward
# 6                     GK    64500000.0                 GK  Goalkeaper
# 7                     LW    90500000.0                 LW     Forward
# 8                 CDM CM    79000000.0                CDM    Midfield
# 9                     ST    77000000.0                 ST     Forward
# 10                    CB    52000000.0                 CB    Backward
# 11             RM CM CAM    83000000.0                 RM    Midfield
# 12                    GK    59000000.0                 GK  Goalkeaper
# 13           RM LW ST LM    67500000.0                 RM    Midfield
# 14                CDM CM    57000000.0                CDM    Midfield
# 15                    RW    69500000.0                 RW     Forward
# 16                    ST    66500000.0                 ST     Forward
# 17                    CB    38000000.0                 CB    Backward
# 18                    GK     4500000.0                 GK  Goalkeaper
# 19                ST CAM    79000000.0                 ST     Forward
# 20                    GK    57000000.0                 GK  Goalkeaper
# 21              LW RW ST    75000000.0                 LW     Forward
# 22            CDM CAM CM    70500000.0                CDM    Midfield
# 23                    ST    61000000.0                 ST     Forward
# 24                    CB    44000000.0                 CB    Backward
# 25                    CB    48000000.0                 CB    Backward
# 26                    CB    40000000.0                 CB    Backward
# 27                    CB    48000000.0                 CB    Backward
# 28                RW CAM    60000000.0                 RW     Forward
# 29                    GK    38000000.0                 GK  Goalkeaper
# ...                   ...          ...                ...         ...
# 17950              LM LB       60000.0                 LM         NaN
# 17951                 GK       40000.0                 GK         NaN
# 17952                 CM       60000.0                 CM         NaN
# 17953              RB CM       60000.0                 RB         NaN
# 17954                 LM       60000.0                 LM         NaN
# 17955                 CM       60000.0                 CM         NaN
# 17956                 CB       50000.0                 CB         NaN
# 17957                 RB       50000.0                 RB         NaN
# 17958              CB RB       40000.0                 CB         NaN
# 17959             CAM ST       60000.0                CAM         NaN
# 17960                CAM       70000.0                CAM         NaN
# 17961                 CB       60000.0                 CB         NaN
# 17962              CB LB       50000.0                 CB         NaN
# 17963                 CM       50000.0                 CM         NaN
# 17964                 CM       60000.0                 CM         NaN
# 17965                 CM       60000.0                 CM         NaN
# 17966                 CM       60000.0                 CM         NaN
# 17967                 RB       60000.0                 RB         NaN
# 17968                 CB       60000.0                 CB         NaN
# 17969                 ST       60000.0                 ST         NaN
# 17970                 CB       40000.0                 CB         NaN
# 17971           ST RM LM       60000.0                 ST         NaN
# 17972       CB LW LWB LB       60000.0                 CB         NaN
# 17973                 CM       50000.0                 CM         NaN
# 17974                 CB       40000.0                 CB         NaN
# 17975                 CM       30000.0                 CM         NaN
# 17976                 GK       50000.0                 GK         NaN
# 17978                 ST       60000.0                 ST         NaN
# 17979                 CM       60000.0                 CM         NaN
# 17980              ST CB       50000.0                 ST         NaN
#
# [17725 rows x 4 columns]

# %%
pos_value = pos_value.drop(columns=["Preferred Positions", "Preferred Position"])

# %%
pos_value
# Out:
#              Value      Região
# 0       95500000.0     Forward
# 1      105000000.0     Forward
# 2      123000000.0     Forward
# 3       97000000.0     Forward
# 4       61000000.0  Goalkeaper
# 5       92000000.0     Forward
# 6       64500000.0  Goalkeaper
# 7       90500000.0     Forward
# 8       79000000.0    Midfield
# 9       77000000.0     Forward
# 10      52000000.0    Backward
# 11      83000000.0    Midfield
# 12      59000000.0  Goalkeaper
# 13      67500000.0    Midfield
# 14      57000000.0    Midfield
# 15      69500000.0     Forward
# 16      66500000.0     Forward
# 17      38000000.0    Backward
# 18       4500000.0  Goalkeaper
# 19      79000000.0     Forward
# 20      57000000.0  Goalkeaper
# 21      75000000.0     Forward
# 22      70500000.0    Midfield
# 23      61000000.0     Forward
# 24      44000000.0    Backward
# 25      48000000.0    Backward
# 26      40000000.0    Backward
# 27      48000000.0    Backward
# 28      60000000.0     Forward
# 29      38000000.0  Goalkeaper
# ...            ...         ...
# 17950      60000.0         NaN
# 17951      40000.0         NaN
# 17952      60000.0         NaN
# 17953      60000.0         NaN
# 17954      60000.0         NaN
# 17955      60000.0         NaN
# 17956      50000.0         NaN
# 17957      50000.0         NaN
# 17958      40000.0         NaN
# 17959      60000.0         NaN
# 17960      70000.0         NaN
# 17961      60000.0         NaN
# 17962      50000.0         NaN
# 17963      50000.0         NaN
# 17964      60000.0         NaN
# 17965      60000.0         NaN
# 17966      60000.0         NaN
# 17967      60000.0         NaN
# 17968      60000.0         NaN
# 17969      60000.0         NaN
# 17970      40000.0         NaN
# 17971      60000.0         NaN
# 17972      60000.0         NaN
# 17973      50000.0         NaN
# 17974      40000.0         NaN
# 17975      30000.0         NaN
# 17976      50000.0         NaN
# 17978      60000.0         NaN
# 17979      60000.0         NaN
# 17980      50000.0         NaN
#
# [17725 rows x 2 columns]

# %%
player_attributes["Value"] = fifa.Value

# %%
player_attributes["Age"] = fifa.Age

# %%
player_attributes = player_attributes.dropna()

# %%
player_attributes.head()
# Out:
#    Acceleration  Aggression  Agility  Balance  Ball control  Composure  \
# 0            89          63       89       63            93         95
# 1            92          48       90       95            95         96
# 2            94          56       96       82            95         92
# 3            88          78       86       60            91         83
# 4            58          29       52       35            48         70
#
#    Crossing  Curve  Dribbling  Finishing ...   Shot power  Sliding tackle  \
# 0        85     81         91         94 ...           94              23
# 1        77     89         97         95 ...           85              26
# 2        75     81         96         89 ...           80              33
# 3        77     86         86         94 ...           87              38
# 4        15     14         30         13 ...           25              11
#
#    Sprint speed  Stamina  Standing tackle  Strength  Vision  Volleys  \
# 0            91       92               31        80      85       88
# 1            87       73               28        59      90       85
# 2            90       78               24        53      80       83
# 3            77       89               45        80      84       88
# 4            61       44               10        83      70       11
#
#          Value  Age
# 0   95500000.0   32
# 1  105000000.0   30
# 2  123000000.0   25
# 3   97000000.0   30
# 4   61000000.0   31
#
# [5 rows x 37 columns]

# %%
plt.figure(figsize=(20, 5))

plt.scatter(player_attributes["Acceleration"], player_attributes.Value);
plt.subplot(141);

plt.scatter(player_attributes["Aggression"], player_attributes.Value);
plt.subplot(142);

plt.scatter(player_attributes["Agility"], player_attributes.Value);
plt.subplot(143);

plt.scatter(player_attributes["Balance"], player_attributes.Value);
plt.subplot(144);




plt.tight_layout()
plt.show()

# %%
print(player_attributes.columns)
# Out:
# Index(['Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball control',
#        'Composure', 'Crossing', 'Curve', 'Dribbling', 'Finishing',
#        'Free kick accuracy', 'GK diving', 'GK handling', 'GK kicking',
#        'GK positioning', 'GK reflexes', 'Heading accuracy', 'ID',
#        'Interceptions', 'Jumping', 'Long passing', 'Long shots', 'Marking',
#        'Penalties', 'Positioning', 'Reactions', 'Short passing', 'Shot power',
#        'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
#        'Strength', 'Vision', 'Volleys', 'Value', 'Age'],
#       dtype='object')

# %%
len(player_attributes.columns)
# Out:
# 37

# %%
X = player_attributes[['Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball control',
       'Composure', 'Crossing', 'Curve', 'Dribbling', 'Finishing',
       'Free kick accuracy', 'GK diving', 'GK handling', 'GK kicking',
       'GK positioning', 'GK reflexes', 'Heading accuracy',
       'Interceptions', 'Jumping', 'Long passing', 'Long shots', 'Marking',
       'Penalties', 'Positioning', 'Reactions', 'Short passing', 'Shot power',
       'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
       'Strength', 'Vision', 'Volleys', 'Age']]

# %%
y = player_attributes.Value

# %%
#from sklearn.linear_model import LinearRegression
#model = LinearRegression();

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()

from sklearn.metrics import mean_squared_error

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=22)

model.fit(X_train,y_train)
y_pred = model.predict(X_test)
r_quadrado = 1 - mean_squared_error(y_test, y_pred) / np.var(y_test)
r_quadrado
# Out:
# C:\Users\VICTOR HABIB\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.8670075593313943

# %%
model
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
valor = model.feature_importances_

# %%
model_value = dict(zip(list(X_train.columns),model.feature_importances_))

# %%
model_value
# Out:
# {'Acceleration': 0.003473905798327992,
#  'Age': 0.03873903439058666,
#  'Aggression': 0.0027405802544190586,
#  'Agility': 0.0019624802570198064,
#  'Balance': 0.0022607815413880406,
#  'Ball control': 0.14206349501728008,
#  'Composure': 0.005798415198106041,
#  'Crossing': 0.0034543791087169916,
#  'Curve': 0.001554062364477808,
#  'Dribbling': 0.023353327669891573,
#  'Finishing': 0.01905420165039901,
#  'Free kick accuracy': 0.008278566552810474,
#  'GK diving': 0.003615429907610633,
#  'GK handling': 0.0134426736479509,
#  'GK kicking': 0.0032236500642163607,
#  'GK positioning': 0.004495256796765957,
#  'GK reflexes': 0.009187884819807824,
#  'Heading accuracy': 0.011991140409634749,
#  'Interceptions': 0.009530270122141816,
#  'Jumping': 0.004243983215545073,
#  'Long passing': 0.0040233819677613115,
#  'Long shots': 0.038259128160432865,
#  'Marking': 0.004534598560890514,
#  'Penalties': 0.001235314944669061,
#  'Positioning': 0.008393214706292586,
#  'Reactions': 0.5511390172155449,
#  'Short passing': 0.008549963124829967,
#  'Shot power': 0.00552466698703887,
#  'Sliding tackle': 0.01179083916491257,
#  'Sprint speed': 0.007166687261576092,
#  'Stamina': 0.004515711860034904,
#  'Standing tackle': 0.03165323385386042,
#  'Strength': 0.005072232935619226,
#  'Vision': 0.003987123124199447,
#  'Volleys': 0.0016913673452403784}

# %%
plt.figure(figsize=(20,15))
xgb.plot_importance(model_value, ax=plt.gca());

# %%
fifa.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball control',
#        'Composure', 'Crossing', 'Curve', 'Dribbling', 'Finishing',
#        'Free kick accuracy', 'GK diving', 'GK handling', 'GK kicking',
#        'GK positioning', 'GK reflexes', 'Heading accuracy', 'Interceptions',
#        'Jumping', 'Long passing', 'Long shots', 'Marking', 'Penalties',
#        'Positioning', 'Reactions', 'Short passing', 'Shot power',
#        'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
#        'Strength', 'Vision', 'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'ID',
#        'LAM', 'LB', 'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB',
#        'Preferred Positions', 'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM',
#        'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
fifa = fifa.drop(columns=["Unnamed: 0", "Name", "Photo", "Nationality", "Flag", "Overall"])

# %%
y=[]

for hability in model_value:
    y.append(model_value[hability])
    
y.sort(key=float,reverse=True)    
x=range(len(y))    
plt.bar(x,y,width=0.6,color='blue')
plt.show()
